# %%
import numpy as np
import pandas as pd
import pylab as pl
import matplotlib.pyplot as plt
import seaborn as sns
import pydot
import subprocess

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import export_graphviz
from sklearn.tree import DecisionTreeClassifier

plt.style.use('ggplot')
# %matplotlib inline

# %%
df=pd.read_csv("/Users/daniilvdovinov/Desktop/DATA-ANALYSIS/Homework/Homework3/diabetes.csv",encoding="cp1251")
print(df.shape)
print(df.info())
df
# Out:
# (768, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# ...

# %%
df.at[df.Insulin == 0, 'Insulin'] = df.Insulin[df.Insulin != 0].median()
df.at[df.BloodPressure == 0, 'BloodPressure'] = df.BloodPressure[df.BloodPressure != 0].median()

# %%
x=df[df.columns.drop('Outcome')]
y=df.values[::, -1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
y_train = y_train.astype(int)
y_test = y_test.astype(int)

# %%
tree=DecisionTreeClassifier(criterion='gini', max_depth=5, min_samples_leaf=20)
tree.fit(x_train, y_train)

print('Результат на обучающей выборке: ', tree.score(x_train,y_train))
print('Результат на тестовой выборке: ',tree.score(x_test, y_test))
# Out:
# Результат на обучающей выборке:  0.8044692737430168
# Результат на тестовой выборке:  0.8138528138528138

# %%
export_graphviz(tree, out_file='/Users/daniilvdovinov/Desktop/DATA-ANALYSIS/Homework/Homework3/Diabetes_tree.dot', 
               rounded = True, proportion = False, 
                precision = 2, filled = True,feature_names=x.columns)
(graph, ) = pydot.graph_from_dot_file('/Users/daniilvdovinov/Desktop/DATA-ANALYSIS/Homework/Homework3/Diabetes_tree.dot')
graph.write_png('/Users/daniilvdovinov/Desktop/DATA-ANALYSIS/Homework/Homework3/Diabetes_tree.png')

# %%
tree=DecisionTreeClassifier(criterion='entropy', max_depth=6, min_samples_leaf=10)
tree.fit(x_train, y_train)

print('Результат на обучающей выборке: ', tree.score(x_train,y_train))
print('Результат на тестовой выборке: ',tree.score(x_test, y_test))
# Out:
# Результат на обучающей выборке:  0.8212290502793296
# Результат на тестовой выборке:  0.8051948051948052
